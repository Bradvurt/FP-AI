# %% [markdown]
# Лабораторная работа №2
#
# Классификация самолетов: военный или гражданский
#
# **Используемые модели:**
# - ResNet-50 (microsoft/resnet-50)
# - Vision Transformer (google/vit-base-patch16-224)
#
# **Датасет:** 30 изображений самолетов (15 гражданских, 15 военных)
#
# Выполнили:
# - Гуреева Алина
# - Тысячный Влад
#
# группа М8О-102СВ-25

# %%
import requests
import time
import os
import base64 #для кодирования изображений
from huggingface_hub import HfApi

# %% [markdown]
# Константы и глобальные переменные

# %%
# Глобальные константы
DATASET_FOLDER = "datasetAirplanes"

API_TOKEN = "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"

# Ссылки на модели
RESNET_URL = "https://router.huggingface.co/hf-inference/models/microsoft/resnet-50"
VIT_URL = "https://router.huggingface.co/hf-inference/models/google/vit-base-patch16-224"

# Заголовки для HTTP-запросов
headers = {
    "Authorization": f"Bearer {API_TOKEN}",
    "Content-Type": "application/json"
}

# %%
def get_sorted_images(folder):

    files = os.listdir(folder)

    # Берём только картинки
    images = [f for f in files if f.lower().endswith((".jpg", ".jpeg", ".png"))]

    # Сортируем по числу перед точкой
    images.sort(key=lambda name: int(name.split('.')[0]))

    return images

# %%
# Получаем отсортированный список изображений
sorted_images = get_sorted_images(DATASET_FOLDER)
print(sorted_images)
# Out:
# ['1.jpeg', '2.jpg', '3.jpg', '4.jpg', '5.jpeg', '6.jpeg', '7.jpeg', '8.jpeg', '9.jpg', '10.jpg', '11.jpg', '12.jpg', '13.jpeg', '14.jpeg', '15.jpg', '16.jpg', '17.jpg', '18.jpeg', '19.jpeg', '20.jpeg', '21.jpg', '22.jpeg', '23.jpeg', '24.jpg', '25.jpeg', '26.jpg', '27.jpg', '28.jpeg', '29.jpg', '30.jpeg']

# %%
# Проверка токена (если активирован, то вернет json с моими данными)
r = requests.get("https://huggingface.co/api/whoami-v2", headers=headers)

print(r.json())
# Out:
# {'type': 'user', 'id': '6918cc3764f6e0b44b3ec420', 'name': 'gureeva017', 'fullname': 'Gureeva Alina', 'email': 'gureeva017@gmail.com', 'emailVerified': True, 'canPay': False, 'periodEnd': None, 'isPro': False, 'avatarUrl': '/avatars/a89491c7d8e6937dcc97bcb9b2a2c2ea.svg', 'orgs': [], 'auth': {'type': 'access_token', 'accessToken': {'displayName': 'colab_lab2', 'role': 'read', 'createdAt': '2025-11-15T18:57:34.525Z'}}}

# %% [markdown]
# Проверка статуса модели

# %%
def check_model_status(url):
    response = requests.get(url, headers=headers)
    print(f"   Status: {response.status_code}")
    if response.status_code == 200:
        print("   Model is accessible")
    else:
        print(f"   Error: {response.text}")

print("ResNet:")
check_model_status(RESNET_URL)
print()
print("ViT")
check_model_status(VIT_URL)
# Out:
# ResNet:
#    Status: 200
#    Model is accessible
#
# ViT
#    Status: 200
#    Model is accessible

# %% [markdown]
# Функции для отправки изображения в модель

# %%
def query_model(api_url, image_path):
    """Отправляет запрос к модели на HuggingFace"""

    # Читаем и кодируем изображение
    with open(image_path, "rb") as f:
        image_b64 = base64.b64encode(f.read()).decode()

    # Формируем запрос
    data = {
        "inputs": image_b64
    }

    response = requests.post(api_url, headers=headers, json=data)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.text}")
        return None

# %% [markdown]
# Разбор ответа от модели (военный / гражданский самолет)

# %%
def parse_answer(result):

    military_keywords = [
    # Базовые слова
    'military', 'war', 'combat', 'fighter', 'bomber', 'attack',
    'interceptor', 'multirole', 'stealth', 'surveillance', 'reconnaissance',
    'navy', 'airforce', 'army', 'marines',

    # Типы военных самолётов
    'jet fighter', 'fighter jet', 'strike aircraft', 'close air support',
    'drone', 'uav', 'ucav',

    # Военные прилагательные
    'tactical', 'strategic', 'supersonic', 'mach', 'afterburner',
    'air superiority', 'dogfight',
    ]

    civil_keywords = [
    # Базовые
    'civil', 'civilian', 'commercial', 'passenger', 'airliner',
    'cargo', 'transport', 'commuter', 'regional',

    # Типы гражданских самолётов
    'jetliner', 'widebody', 'narrowbody', 'turboprop',
    'business jet', 'private jet',
    ]
    
    military_score = 0
    civil_score = 0

    # Считаем упоминания
    for pred in result[:3]:
        print(f"  {pred['label']}: {pred['score']:.4f}")
        
        is_military = any(1 for kw in military_keywords if kw in pred["label"])
        is_civil = any(1 for kw in civil_keywords if kw in pred["label"])

        military_score += is_military * pred["score"]
        civil_score += is_civil * pred["score"]

    # Определяем класс
    if military_score > civil_score:
        return "military"
    elif civil_score > military_score:
        return "civil"
    else:
        return "unknown"

# %% [markdown]
# Загружает список файлов изображений из указанной папки

# %%
def load_dataset(folder_path):
    if not os.path.exists(folder_path):
        print(f"ОШИБКА: Папка {folder_path} не найдена!")
        print("Загрузи папку с датасетом в Colab или укажи правильный путь")
        return None

    # Получаем отсортированный список изображений (по числу в имени файла)
    all_files = get_sorted_images(folder_path)

    if len(all_files) < 30:
        print(f"ВНИМАНИЕ: Найдено только {len(all_files)} изображений, ожидалось 30")

    # Первые 15 - гражданские, остальные 15 - военные
    civil_files = [os.path.join(folder_path, f) for f in all_files[:15]]
    military_files = [os.path.join(folder_path, f) for f in all_files[15:30]]

    print(f"Загружено изображений:")
    print(f"  Гражданских: {len(civil_files)}")
    print(f"  Военных: {len(military_files)}")

    return {"civil": civil_files, "military": military_files}

dataset = load_dataset(DATASET_FOLDER)

if dataset is None:
    print(f"Остановка программы. Исправь путь к датасету и запусти снова.")
    exit()
# Out:
# Загружено изображений:
#   Гражданских: 15
#   Военных: 15

# %% [markdown]
# Запуск классификации всех изображений

# %%
results = {
    "resnet": {"predictions": [], "true_labels": []},
    "vit": {"predictions": [], "true_labels": []}
}

print("Начинаем классификацию\n")

# Проходим по всем изображениям
for true_label, images in dataset.items():
    for i, img_path in enumerate(images):
        print(f"\n{'='*50}")
        print(f"Изображение: {img_path} (настоящая метка: {true_label})")

        # Классификация с помощью ResNet-50
        print(f"Запрос к ResNet...")
        resnet_response = query_model(RESNET_URL, img_path)
        resnet_pred = parse_answer(resnet_response)
        results["resnet"]["predictions"].append(resnet_pred)
        results["resnet"]["true_labels"].append(true_label)
        print(f"ResNet ответ: {resnet_pred}")
        print()

        time.sleep(2)

        # Классификация с помощью Vision Transformer
        print("Запрос к ViT...")
        vit_response = query_model(VIT_URL, img_path)
        vit_pred = parse_answer(vit_response)
        results["vit"]["predictions"].append(vit_pred)
        results["vit"]["true_labels"].append(true_label)
        print(f"ViT ответ: {vit_pred}")

        time.sleep(2)
# Out:
# Начинаем классификацию
#
#
# ==================================================
# Изображение: datasetAirplance\1.jpeg (настоящая метка: civil)
# Запрос к ResNet...
#   airliner: 0.9997
#   wing: 0.0002
#   space shuttle: 0.0000
# ResNet ответ: civil
#
# Запрос к ViT...
#   airliner: 0.9938
#   wing: 0.0023
#   warplane, military plane: 0.0018
# ViT ответ: civil
#
# ==================================================
# Изображение: datasetAirplance\2.jpg (настоящая метка: civil)
# Запрос к ResNet...
#   warplane, military plane: 0.9042
#   missile: 0.0311
#   wing: 0.0248
# ResNet ответ: military
#
# Запрос к ViT...
#   airliner: 0.8795
#   wing: 0.0604
#   warplane, military plane: 0.0442
# ViT ответ: civil
#
# ==================================================
# Изображение: datasetAirplance\3.jpg (настоящая метка: civil)
# Запрос к ResNet...
#   airliner: 0.9962
#   wing: 0.0031
#   tiger shark, Galeocerdo cuvieri: 0.0000
# ResNet ответ: civil
#
# Запрос к ViT...
#   airliner: 0.9950
#   wing: 0.0034
#   warplane, military plane: 0.0004
# ViT ответ: civil
#
# ==================================================
# Изображение: datasetAirplance\4.jpg (настоящая метка: civil)
# Запрос к ResNet...
#   airliner: 0.9994
#   wing: 0.0003
#   police van, police wagon, paddy wagon, patrol wagon, wagon, black Maria: 0.0000
# ResNet ответ: civil
#
# Запрос к ViT...
#   airliner: 0.9946
#   wing: 0.0023
#   warplane, military plane: 0.0009
# ViT ответ: civil
#
# ==================================================
# Изображение: datasetAirplance\5.jpeg (настоящая метка: civil)
# Запрос к ResNet...
#   airliner: 0.9992
#   wing: 0.0002
#   racer, race car, racing car: 0.0001
# ResNet ответ: civil
#
# Запрос к ViT...
#   airliner: 0.9745
#   wing: 0.0206
#   warplane, military plane: 0.0010
# ViT ответ: civil
#
# ==================================================
# Изображение: datasetAirplance\6.jpeg (настоящая метка: civil)
# Запрос к ResNet...
#   airliner: 0.9710
#   missile: 0.0092
#   warplane, military plane: 0.0039
# ResNet ответ: civil
#
# Запрос к ViT...
#   airliner: 0.9849
#   wing: 0.0046
#   warplane, military plane: 0.0009
# ViT ответ: civil
#
# ==================================================
# Изображение: datasetAirplance\7.jpeg (настоящая метка: civil)
# Запрос к ResNet...
#   airliner: 0.9995
#   wing: 0.0004
#   warplane, military plane: 0.0000
# ResNet ответ: civil
#
# Запрос к ViT...
#   airliner: 0.9959
#   wing: 0.0014
#   warplane, military plane: 0.0008
# ViT ответ: civil
#
# ==================================================
# Изображение: datasetAirplance\8.jpeg (настоящая метка: civil)
# Запрос к ResNet...
#   airliner: 0.9591
#   wing: 0.0190
#   warplane, military plane: 0.0074
# ResNet ответ: civil
#
# Запрос к ViT...
#   airliner: 0.9888
#   wing: 0.0081
#   warplane, military plane: 0.0007
# ViT ответ: civil
#
# ==================================================
# Изображение: datasetAirplance\9.jpg (настоящая метка: civil)
# Запрос к ResNet...
#   airliner: 0.9799
#   wing: 0.0116
#   warplane, military plane: 0.0051
# ResNet ответ: civil
#
# Запрос к ViT...
#   airliner: 0.9920
#   wing: 0.0053
#   warplane, military plane: 0.0011
# ViT ответ: civil
#
# ==================================================
# Изображение: datasetAirplance\10.jpg (настоящая метка: civil)
# Запрос к ResNet...
#   airliner: 0.5496
#   wing: 0.4396
#   warplane, military plane: 0.0058
# ResNet ответ: civil
#
# Запрос к ViT...
#   airliner: 0.9835
#   wing: 0.0091
#   warplane, military plane: 0.0020
# ViT ответ: civil
#
# ==================================================
# Изображение: datasetAirplance\11.jpg (настоящая метка: civil)
# Запрос к ResNet...
#   airliner: 0.9996
#   aircraft carrier, carrier, flattop, attack aircraft carrier: 0.0001
#   wing: 0.0001
# ResNet ответ: civil
#
# Запрос к ViT...
#   airliner: 0.9926
#   wing: 0.0030
#   warplane, military plane: 0.0013
# ViT ответ: civil
#
# ==================================================
# Изображение: datasetAirplance\12.jpg (настоящая метка: civil)
# Запрос к ResNet...
#   airliner: 0.9551
#   warplane, military plane: 0.0111
#   wing: 0.0067
# ResNet ответ: civil
#
# Запрос к ViT...
#   airliner: 0.9489
#   wing: 0.0247
#   warplane, military plane: 0.0217
# ViT ответ: civil
#
# ==================================================
# Изображение: datasetAirplance\13.jpeg (настоящая метка: civil)
# Запрос к ResNet...
#   airliner: 0.9978
#   wing: 0.0018
#   projectile, missile: 0.0000
# ResNet ответ: civil
#
# Запрос к ViT...
#   airliner: 0.9940
#   wing: 0.0030
#   warplane, military plane: 0.0009
# ViT ответ: civil
#
# ==================================================
# Изображение: datasetAirplance\14.jpeg (настоящая метка: civil)
# Запрос к ResNet...
#   airliner: 0.9997
#   wing: 0.0001
#   trailer truck, tractor trailer, trucking rig, rig, articulated lorry, semi: 0.0000
# ResNet ответ: civil
#
# Запрос к ViT...
#   airliner: 0.9958
#   wing: 0.0024
#   warplane, military plane: 0.0004
# ViT ответ: civil
#
# ==================================================
# Изображение: datasetAirplance\15.jpg (настоящая метка: civil)
# Запрос к ResNet...
#   airliner: 0.9999
#   wing: 0.0001
#   warplane, military plane: 0.0000
# ResNet ответ: civil
#
# Запрос к ViT...
#   airliner: 0.9950
#   wing: 0.0017
#   warplane, military plane: 0.0008
# ViT ответ: civil
#
# ==================================================
# Изображение: datasetAirplance\16.jpg (настоящая метка: military)
# Запрос к ResNet...
#   warplane, military plane: 0.9973
#   projectile, missile: 0.0016
#   missile: 0.0004
# ResNet ответ: military
#
# Запрос к ViT...
#   warplane, military plane: 0.9367
#   airliner: 0.0465
#   projectile, missile: 0.0030
# ViT ответ: military
#
# ==================================================
# Изображение: datasetAirplance\17.jpg (настоящая метка: military)
# Запрос к ResNet...
#   warplane, military plane: 0.9999
#   wing: 0.0000
#   projectile, missile: 0.0000
# ResNet ответ: military
#
# Запрос к ViT...
#   warplane, military plane: 0.9632
#   wing: 0.0125
#   projectile, missile: 0.0069
# ViT ответ: military
#
# ==================================================
# Изображение: datasetAirplance\18.jpeg (настоящая метка: military)
# Запрос к ResNet...
#   warplane, military plane: 0.9999
#   missile: 0.0000
#   projectile, missile: 0.0000
# ResNet ответ: military
#
# Запрос к ViT...
#   warplane, military plane: 0.9679
#   wing: 0.0130
#   aircraft carrier, carrier, flattop, attack aircraft carrier: 0.0061
# ViT ответ: military
#
# ==================================================
# Изображение: datasetAirplance\19.jpeg (настоящая метка: military)
# Запрос к ResNet...
#   warplane, military plane: 0.9799
#   airliner: 0.0071
#   projectile, missile: 0.0048
# ResNet ответ: military
#
# Запрос к ViT...
#   warplane, military plane: 0.9401
#   airliner: 0.0253
#   wing: 0.0170
# ViT ответ: military
#
# ==================================================
# Изображение: datasetAirplance\20.jpeg (настоящая метка: military)
# Запрос к ResNet...
#   warplane, military plane: 0.8983
#   airliner: 0.0394
#   projectile, missile: 0.0244
# ResNet ответ: military
#
# Запрос к ViT...
#   airliner: 0.7338
#   warplane, military plane: 0.2489
#   wing: 0.0086
# ViT ответ: civil
#
# ==================================================
# Изображение: datasetAirplance\21.jpg (настоящая метка: military)
# Запрос к ResNet...
#   wing: 0.9926
#   warplane, military plane: 0.0052
#   parachute, chute: 0.0013
# ResNet ответ: military
#
# Запрос к ViT...
#   warplane, military plane: 0.7107
#   wing: 0.2196
#   projectile, missile: 0.0238
# ViT ответ: military
#
# ==================================================
# Изображение: datasetAirplance\22.jpeg (настоящая метка: military)
# Запрос к ResNet...
#   warplane, military plane: 0.9830
#   missile: 0.0062
#   aircraft carrier, carrier, flattop, attack aircraft carrier: 0.0058
# ResNet ответ: military
#
# Запрос к ViT...
#   aircraft carrier, carrier, flattop, attack aircraft carrier: 0.9190
#   warplane, military plane: 0.0581
#   projectile, missile: 0.0115
# ViT ответ: military
#
# ==================================================
# Изображение: datasetAirplance\23.jpeg (настоящая метка: military)
# Запрос к ResNet...
#   warplane, military plane: 0.5568
#   projectile, missile: 0.3137
#   missile: 0.1049
# ResNet ответ: military
#
# Запрос к ViT...
#   warplane, military plane: 0.8155
#   airliner: 0.0740
#   projectile, missile: 0.0618
# ViT ответ: military
#
# ==================================================
# Изображение: datasetAirplance\24.jpg (настоящая метка: military)
# Запрос к ResNet...
#   warplane, military plane: 0.9566
#   wing: 0.0167
#   projectile, missile: 0.0049
# ResNet ответ: military
#
# Запрос к ViT...
#   warplane, military plane: 0.8138
#   airliner: 0.0899
#   projectile, missile: 0.0274
# ViT ответ: military
#
# ==================================================
# Изображение: datasetAirplance\25.jpeg (настоящая метка: military)
# Запрос к ResNet...
#   warplane, military plane: 0.9998
#   projectile, missile: 0.0001
#   missile: 0.0000
# ResNet ответ: military
#
# Запрос к ViT...
#   warplane, military plane: 0.7872
#   projectile, missile: 0.1159
#   missile: 0.0709
# ViT ответ: military
#
# ==================================================
# Изображение: datasetAirplance\26.jpg (настоящая метка: military)
# Запрос к ResNet...
#   warplane, military plane: 0.9784
#   missile: 0.0080
#   airship, dirigible: 0.0051
# ResNet ответ: military
#
# Запрос к ViT...
#   warplane, military plane: 0.6944
#   space shuttle: 0.1816
#   airliner: 0.0456
# ViT ответ: military
#
# ==================================================
# Изображение: datasetAirplance\27.jpg (настоящая метка: military)
# Запрос к ResNet...
#   warplane, military plane: 0.9592
#   airliner: 0.0199
#   aircraft carrier, carrier, flattop, attack aircraft carrier: 0.0045
# ResNet ответ: military
#
# Запрос к ViT...
#   warplane, military plane: 0.8934
#   wing: 0.0497
#   aircraft carrier, carrier, flattop, attack aircraft carrier: 0.0205
# ViT ответ: military
#
# ==================================================
# Изображение: datasetAirplance\28.jpeg (настоящая метка: military)
# Запрос к ResNet...
#   aircraft carrier, carrier, flattop, attack aircraft carrier: 1.0000
#   warplane, military plane: 0.0000
#   missile: 0.0000
# ResNet ответ: military
#
# Запрос к ViT...
#   aircraft carrier, carrier, flattop, attack aircraft carrier: 0.9518
#   warplane, military plane: 0.0383
#   projectile, missile: 0.0043
# ViT ответ: military
#
# ==================================================
# Изображение: datasetAirplance\29.jpg (настоящая метка: military)
# Запрос к ResNet...
#   warplane, military plane: 0.9981
#   wing: 0.0004
#   aircraft carrier, carrier, flattop, attack aircraft carrier: 0.0002
# ResNet ответ: military
#
# Запрос к ViT...
#   warplane, military plane: 0.9451
#   projectile, missile: 0.0160
#   missile: 0.0136
# ViT ответ: military
#
# ==================================================
# Изображение: datasetAirplance\30.jpeg (настоящая метка: military)
# Запрос к ResNet...
#   warplane, military plane: 0.9963
#   missile: 0.0012
#   projectile, missile: 0.0010
# ResNet ответ: military
#
# Запрос к ViT...
#   warplane, military plane: 0.9513
#   projectile, missile: 0.0129
#   aircraft carrier, carrier, flattop, attack aircraft carrier: 0.0079
# ViT ответ: military

# %% [markdown]
# Метрики: Accuracy, Precision, Recall, F1

# %% [markdown]
# В нашей задаче "положительный" класс = "military" (военный самолет).
#     "Отрицательный" класс = "civil" (гражданский самолет)

# %%
def calculate_metrics(y_true, y_pred):
    # Убираем 'unknown' из подсчета
    filtered = [(t, p) for t, p in zip(y_true, y_pred) if p != "unknown"]

    if not filtered:
        return {"accuracy": 0, "precision": 0, "recall": 0, "f1": 0}

    y_true_filtered, y_pred_filtered = zip(*filtered)

    # Вычисляем True Positives, False Positives, False Negatives, True Negatives
    tp = sum(1 for t, p in zip(y_true_filtered, y_pred_filtered) if t == "military" and p == "military")
    fp = sum(1 for t, p in zip(y_true_filtered, y_pred_filtered) if t == "civil" and p == "military")
    fn = sum(1 for t, p in zip(y_true_filtered, y_pred_filtered) if t == "military" and p == "civil")
    tn = sum(1 for t, p in zip(y_true_filtered, y_pred_filtered) if t == "civil" and p == "civil")

    # Вычисляем метрики
    accuracy = (tp + tn) / len(y_true_filtered) if len(y_true_filtered) > 0 else 0
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    return {
        "accuracy": round(accuracy, 3),
        "precision": round(precision, 3),
        "recall": round(recall, 3),
        "f1": round(f1, 3)
    }

# %%
for model_name, data in results.items():
    print(f"\n{model_name.upper()}:")
    metrics = calculate_metrics(data["true_labels"], data["predictions"])
    print(f"  Accuracy:  {metrics['accuracy']}")
    print(f"  Precision: {metrics['precision']}")
    print(f"  Recall:    {metrics['recall']}")
    print(f"  F1-score:  {metrics['f1']}")
# Out:
# RESNET:
#   Accuracy:  0.967
#   Precision: 0.938
#   Recall:    1.0
#   F1-score:  0.968
#
# VIT:
#   Accuracy:  0.967
#   Precision: 1.0
#   Recall:    0.933
#   F1-score:  0.966

# %% [markdown]
# Сравнение моделей

# %%
print("СРАВНЕНИЕ МОДЕЛЕЙ")

# Вычисляем метрики для обеих моделей
resnet_metrics = calculate_metrics(results["resnet"]["true_labels"], results["resnet"]["predictions"])
vit_metrics = calculate_metrics(results["vit"]["true_labels"], results["vit"]["predictions"])

print(f"\nResNet-50 F1-score:  {resnet_metrics['f1']}")
print(f"ViT F1-score:          {vit_metrics['f1']}")

print("\n" + "-"*60)
if resnet_metrics["f1"] > vit_metrics["f1"]:
    print(f"ResNet-50 показала лучший результат")
    print(f"  (F1: {resnet_metrics['f1']} vs {vit_metrics['f1']})")
elif vit_metrics["f1"] > resnet_metrics["f1"]:
    print(f"Vision Transformer показала лучший результат")
    print(f"  (F1: {vit_metrics['f1']} vs {resnet_metrics['f1']})")
else:
    print("Модели показали одинаковый результат")
# Out:
# СРАВНЕНИЕ МОДЕЛЕЙ
#
# ResNet-50 F1-score:  0.968
# ViT F1-score:          0.966
#
# ------------------------------------------------------------
# ResNet-50 показала лучший результат
#   (F1: 0.968 vs 0.966)
